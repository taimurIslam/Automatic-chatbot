# %%
# Import Librarys
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
import pandas as pd

# %%
#Training Process
stemmer = LancasterStemmer()

# %%
stopWords = set(stopwords.words('english'))
other_stop_words = ["?","'s"]
for stop_word in other_stop_words:
    stopWords.add(stop_word)

# %%
data = pd.read_csv('questions.csv')

# %%
data
# Out:
#           class                                           sentence
# 0    question-1                        How to create working area?
# 1    question-1                          How to make working area?
# 2    question-1      What is the process of working area creation?
# 3    question-2                              How to create Samity?
# 4    question-2                               How to create Group?
# 5    question-2             From where and how can we make Samity?
# 6    question-2              From where and how can we make Group?
# 7    question-2                          How to open a new Samity?
# 8    question-2                           How to open a new Group?
# 9    question-3                                 How to add member?
# 10   question-3                             How to add new member?
# 11   question-3    How to perform member admission in microfin360?
# 12   question-4                       How to open savings account?
# 13   question-4                 How to open a new savings account?
# 14   question-4           How to create a general savings account?
# 15   question-5                  How to disburse loan to a member?
# 16   question-5        What is the process of a new loan Disburse?
# 17   question-5                          How to create a new loan?
# 18   question-6         From where we can entry regula collection?
# 19   question-6  What is the process of entering Samity day col...
# 20   question-6      What is the regular collection entry process?
# 21   question-7  How to give posting of without Samity day coll...
# 22   question-7  How to give posting of without Samity day coll...
# 23   question-7   How to enter without Samity day Loan collection?
# 24   question-7  How to enter without Samity day Savings collec...
# 25   question-7  From which menu we can give posting of without...
# 26   question-7  From which menu we can give posting of without...
# 27   question-8                            How to change password?
# 28   question-8                 From where we can change password?
# 29   question-8                 How to change password frequently?
# 30   question-9        How to correct savings deposit wrong entry?
# 31   question-9  What is the process of correcting savings depo...
# 32   question-9  From which menu we can correct wrong deposit e...
# 33  question-10       How to correct loan transaction wrong entry?
# 34  question-10  What is the process of loan transaction wrong ...
# 35  question-10    What should I do for a wrong transaction entry?
# 36  question-11                     From where we can see voucher?
# 37  question-11                              How to check voucher?
# 38  question-11        Which menu to use for showing all vouchers?
# 39  question-12       Where we can entry bank deposit or withdraw?
# 40  question-12                         How to enter bank deposit?
# 41  question-12                  How to give bank deposit posting?
# 42  question-13                How to correct voucher wrong entry?
# 43  question-13  What is the process of correcting voucher wron...
# 44  question-13  What should we do to correct a wrong entry in ...
# 45  question-14                      How to generate auto voucher?
# 46  question-14           From where we can generate auto voucher?
# 47  question-14    What is the process of auto voucher generation?

# %%
data_class_name = data['class'].unique()

# %%
data_class_count = {}
for class_name in data['class']:
    if class_name not in data_class_count:
        data_class_count[class_name] = 1
    else:
        data_class_count[class_name] += 1
len(data_class_count)
# Out:
# 14

# %%
for class_name in data_class_count.keys():
    data_class_count[class_name] = data_class_count[class_name]/len(data_class_count)

# %%
data_class_count
# Out:
# {'question-1': 0.21428571428571427,
#  'question-10': 0.21428571428571427,
#  'question-11': 0.21428571428571427,
#  'question-12': 0.21428571428571427,
#  'question-13': 0.21428571428571427,
#  'question-14': 0.21428571428571427,
#  'question-2': 0.42857142857142855,
#  'question-3': 0.21428571428571427,
#  'question-4': 0.21428571428571427,
#  'question-5': 0.21428571428571427,
#  'question-6': 0.21428571428571427,
#  'question-7': 0.42857142857142855,
#  'question-8': 0.21428571428571427,
#  'question-9': 0.21428571428571427}

# %%
corpus_words = []
for sentence in data['sentence']:
    for word in nltk.word_tokenize(sentence):
        if word not in stopWords:
            stemmed_word = stemmer.stem(word.lower())
            
            if stemmed_word not in corpus_words:
                corpus_words.append(stemmed_word)
            else:
                pass

# %%
corpus_words
# Out:
# ['how',
#  'cre',
#  'work',
#  'are',
#  'mak',
#  'what',
#  'process',
#  'sam',
#  'group',
#  'from',
#  'op',
#  'new',
#  'ad',
#  'memb',
#  'perform',
#  'admit',
#  'microfin360',
#  'sav',
#  'account',
#  'gen',
#  'disburs',
#  'loan',
#  'entry',
#  'regul',
#  'collect',
#  'ent',
#  'day',
#  'giv',
#  'post',
#  'without',
#  'menu',
#  'irregul',
#  'chang',
#  'password',
#  'frequ',
#  'correct',
#  'deposit',
#  'wrong',
#  'transact',
#  'i',
#  'see',
#  'vouch',
#  'check',
#  'which',
#  'us',
#  'show',
#  'wher',
#  'bank',
#  'withdraw',
#  'auto']

# %%
data_class_name_with_word = list(data_class_name)
data_class_name_with_word.insert(0, 'word')
data_class_name_with_word


# for class_name in data_class_name:
# Out:
# ['word',
#  'question-1',
#  'question-2',
#  'question-3',
#  'question-4',
#  'question-5',
#  'question-6',
#  'question-7',
#  'question-8',
#  'question-9',
#  'question-10',
#  'question-11',
#  'question-12',
#  'question-13',
#  'question-14']

# %%
result_data_frame = pd.DataFrame(columns=data_class_name_with_word)

# %%
word_list = pd.Series(corpus_words)

# %%
result_data_frame['word'] = word_list.values

# %%
result_data_frame = result_data_frame.fillna(0)

# %%
a = list(result_data_frame['word'])
a.index('how')
# Out:
# 0

# %%
result_data_frame.iloc[1][0]
# Out:
# 'cre'

# %%
word_list = list(result_data_frame['word'])

for i in range(len(data)):
    for word in nltk.word_tokenize(data['sentence'][i]):
        if word not in stopWords:
         
            stemmed_word = stemmer.stem(word.lower())
                
            if stemmed_word in list(result_data_frame['word']):
                word_position = word_list.index(stemmed_word)
                result_data_frame[]
        
            #else:
                #print('kk')
#                 corpus_words[stemmed_word] +=1
# Out:
#   File "<ipython-input-230-4b2015349104>", line 9
#     .index(stemmed_word)
#     ^
# SyntaxError: invalid syntax

# %%
corpus_words = {}
for class_name in data['class']:
    for sentence in data['sentence']:
        for word in nltk.word_tokenize(sentence):
            if word not in stopWords:
                stemmed_word = stemmer.stem(word.lower())
                
                if stemmed_word not in corpus_words:
                    corpus_words[stemmed_word] =1
                else:
                    corpus_words[stemmed_word] +=1
# Out:
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# ...
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?
# How to create working area?
# How to make working area?
# What is the process of working area creation?
# How to create Samity?
# How to create Group?
# From where and how can we make Samity?
# From where and how can we make Group?
# How to open a new Samity?
# How to open a new Group?
# How to add member?
# How to add new member?
# How to perform member admission in microfin360?
# How to open savings account?
# How to open a new savings account?
# How to create a general savings account?
# How to disburse loan to a member?
# What is the process of a new loan Disburse?
# How to create a new loan?
# From where we can entry regula collection?
# What is the process of entering Samity day collection?
# What is the regular collection entry process?
# How to give posting of without Samity day collection Loan?
# How to give posting of without Samity day collection Savings?
# How to enter without Samity day Loan collection?
# How to enter without Samity day Savings collection?
# From which menu we can give posting of without irregular Loan collection?
# From which menu we can give posting of without irregular Savings collection?
# How to change password?
# From where we can change password?
# How to change password frequently?
# How to correct savings deposit wrong entry?
# What is the process of correcting savings deposit entry?
# From which menu we can correct wrong deposit entry?
# How to correct loan transaction wrong entry?
# What is the process of loan transaction wrong entry?
# What should I do for a wrong transaction entry?
# From where we can see voucher?
# How to check voucher?
# Which menu to use for showing all vouchers?
# Where we can entry bank deposit or withdraw?
# How to enter bank deposit?
# How to give bank deposit posting?
# How to correct voucher wrong entry?
# What is the process of correcting voucher wrong entry?
# What should we do to correct a wrong entry in voucher?
# How to generate auto voucher?
# From where we can generate auto voucher?
# What is the process of auto voucher generation?

# %%
list(result_data_frame['word'])
# Out:
# ['how',
#  'cre',
#  'work',
#  'are',
#  'mak',
#  'what',
#  'process',
#  'sam',
#  'group',
#  'from',
#  'op',
#  'new',
#  'ad',
#  'memb',
#  'perform',
#  'admit',
#  'microfin360',
#  'sav',
#  'account',
#  'gen',
#  'disburs',
#  'loan',
#  'entry',
#  'regul',
#  'collect',
#  'ent',
#  'day',
#  'giv',
#  'post',
#  'without',
#  'menu',
#  'irregul',
#  'chang',
#  'password',
#  'frequ',
#  'correct',
#  'deposit',
#  'wrong',
#  'transact',
#  'i',
#  'see',
#  'vouch',
#  'check',
#  'which',
#  'us',
#  'show',
#  'wher',
#  'bank',
#  'withdraw',
#  'auto']
